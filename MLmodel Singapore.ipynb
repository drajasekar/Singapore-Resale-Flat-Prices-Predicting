# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('combined.csv')
df
# Out:
#         latitude   longitude blk_no            road_name  postal_code  \
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# ...          ...         ...    ...                  ...          ...
# 204794  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 204795  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 204796  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 204797  1.428039  103.850960   462D      YISHUN AVENUE 6       764462
# 204798  1.425324  103.851844   468A     YISHUN STREET 43       761468
#
#                      address      cbd_dist  min_dist_mrt    month        town  \
# 0       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2015-01  ANG MO KIO
# 1       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 204794     674B YISHUN AVE 4  15294.493180   1199.607851  2023-07      YISHUN
# 204795     674B YISHUN AVE 4  15294.493180   1199.607851  2023-07      YISHUN
# 204796     674B YISHUN AVE 4  15294.493180   1199.607851  2023-08      YISHUN
# 204797     462D YISHUN AVE 6  16037.700681   1782.270700  2023-11      YISHUN
# 204798     468A YISHUN ST 43  15737.566112   1928.447262  2023-11      YISHUN
#
#        flat_type block       street_name storey_range  floor_area_sqm  \
# 0         3 ROOM   174  ANG MO KIO AVE 4     07 TO 09            60.0
# 1         3 ROOM   174  ANG MO KIO AVE 4     10 TO 12            60.0
# 2         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            69.0
# 3         2 ROOM   174  ANG MO KIO AVE 4     07 TO 09            45.0
# 4         3 ROOM   174  ANG MO KIO AVE 4     04 TO 06            61.0
# ...          ...   ...               ...          ...             ...
# 204794    5 ROOM  674B      YISHUN AVE 4     10 TO 12           112.0
# 204795    5 ROOM  674B      YISHUN AVE 4     07 TO 09           112.0
# 204796    5 ROOM  674B      YISHUN AVE 4     07 TO 09           112.0
# 204797    4 ROOM  462D      YISHUN AVE 6     10 TO 12            93.0
# 204798    4 ROOM  468A      YISHUN ST 43     04 TO 06            93.0
#
#        flat_model  lease_commence_date     remaining_lease  resale_price  \
# 0        Improved                 1986                  70      255000.0
# 1        Improved                 1986                  69      275000.0
# 2        Improved                 1986                  68      310000.0
# 3        Improved                 1986                  68      253000.0
# 4        Improved                 1986                  68      290000.0
# ...           ...                  ...                 ...           ...
# 204794   Improved                 2018  94 years 05 months      715000.0
# 204795   Improved                 2018  94 years 05 months      720000.0
# 204796   Improved                 2018  94 years 03 months      728000.0
# 204797    Model A                 2019  94 years 10 months      575000.0
# 204798    Model A                 2019            95 years      535000.0
#
#         lease_remain_years
# 0                       62
# 1                       62
# 2                       62
# 3                       62
# 4                       62
# ...                    ...
# 204794                  94
# 204795                  94
# 204796                  94
# 204797                  95
# 204798                  95
#
# [204799 rows x 20 columns]

# %%
df.dtypes
# Out:
# latitude               float64
# longitude              float64
# blk_no                  object
# road_name               object
# postal_code              int64
# address                 object
# cbd_dist               float64
# min_dist_mrt           float64
# month                   object
# town                    object
# flat_type               object
# block                   object
# street_name             object
# storey_range            object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# remaining_lease         object
# resale_price           float64
# lease_remain_years       int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# latitude               0
# longitude              0
# blk_no                 0
# road_name              0
# postal_code            0
# address                0
# cbd_dist               0
# min_dist_mrt           0
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# storey_range           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# remaining_lease        0
# resale_price           0
# lease_remain_years     0
# dtype: int64

# %%
#Minor Data Preprocessing for Combined Data

# %%
import statistics

def get_median(x):
    split_list = x.split(' TO ')
    float_list = [float(i) for i in split_list]
    median = statistics.median(float_list)
    return median

df['storey_median'] = df['storey_range'].apply(lambda x: get_median(x))
df
# Out:
#         latitude   longitude blk_no            road_name  postal_code  \
# 0       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 1       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 2       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 3       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# 4       1.375097  103.837619    174  ANG MO KIO AVENUE 4       560174
# ...          ...         ...    ...                  ...          ...
# 204794  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 204795  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 204796  1.421073  103.843117   674B      YISHUN AVENUE 4       762674
# 204797  1.428039  103.850960   462D      YISHUN AVENUE 6       764462
# 204798  1.425324  103.851844   468A     YISHUN STREET 43       761468
#
#                      address      cbd_dist  min_dist_mrt    month        town  \
# 0       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2015-01  ANG MO KIO
# 1       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2015-12  ANG MO KIO
# 2       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2016-05  ANG MO KIO
# 3       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2016-06  ANG MO KIO
# 4       174 ANG MO KIO AVE 4  10296.855747   1098.721074  2016-11  ANG MO KIO
# ...                      ...           ...           ...      ...         ...
# 204794     674B YISHUN AVE 4  15294.493180   1199.607851  2023-07      YISHUN
# 204795     674B YISHUN AVE 4  15294.493180   1199.607851  2023-07      YISHUN
# 204796     674B YISHUN AVE 4  15294.493180   1199.607851  2023-08      YISHUN
# 204797     462D YISHUN AVE 6  16037.700681   1782.270700  2023-11      YISHUN
# 204798     468A YISHUN ST 43  15737.566112   1928.447262  2023-11      YISHUN
#
#         ... block       street_name storey_range floor_area_sqm  flat_model  \
# 0       ...   174  ANG MO KIO AVE 4     07 TO 09           60.0    Improved
# 1       ...   174  ANG MO KIO AVE 4     10 TO 12           60.0    Improved
# 2       ...   174  ANG MO KIO AVE 4     04 TO 06           69.0    Improved
# 3       ...   174  ANG MO KIO AVE 4     07 TO 09           45.0    Improved
# 4       ...   174  ANG MO KIO AVE 4     04 TO 06           61.0    Improved
# ...     ...   ...               ...          ...            ...         ...
# 204794  ...  674B      YISHUN AVE 4     10 TO 12          112.0    Improved
# 204795  ...  674B      YISHUN AVE 4     07 TO 09          112.0    Improved
# 204796  ...  674B      YISHUN AVE 4     07 TO 09          112.0    Improved
# 204797  ...  462D      YISHUN AVE 6     10 TO 12           93.0     Model A
# 204798  ...  468A      YISHUN ST 43     04 TO 06           93.0     Model A
#
#        lease_commence_date     remaining_lease resale_price  \
# 0                     1986                  70     255000.0
# 1                     1986                  69     275000.0
# 2                     1986                  68     310000.0
# 3                     1986                  68     253000.0
# 4                     1986                  68     290000.0
# ...                    ...                 ...          ...
# 204794                2018  94 years 05 months     715000.0
# 204795                2018  94 years 05 months     720000.0
# 204796                2018  94 years 03 months     728000.0
# 204797                2019  94 years 10 months     575000.0
# 204798                2019            95 years     535000.0
#
#         lease_remain_years  storey_median
# 0                       62            8.0
# 1                       62           11.0
# 2                       62            5.0
# 3                       62            8.0
# 4                       62            5.0
# ...                    ...            ...
# 204794                  94           11.0
# 204795                  94            8.0
# 204796                  94            8.0
# 204797                  95           11.0
# 204798                  95            5.0
#
# [204799 rows x 21 columns]

# %%
scope_df = df[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']]
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       10296.855747   1098.721074            60.0                  62
# 1       10296.855747   1098.721074            60.0                  62
# 2       10296.855747   1098.721074            69.0                  62
# 3       10296.855747   1098.721074            45.0                  62
# 4       10296.855747   1098.721074            61.0                  62
# ...              ...           ...             ...                 ...
# 204794  15294.493180   1199.607851           112.0                  94
# 204795  15294.493180   1199.607851           112.0                  94
# 204796  15294.493180   1199.607851           112.0                  94
# 204797  16037.700681   1782.270700            93.0                  95
# 204798  15737.566112   1928.447262            93.0                  95
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 204794           11.0      715000.0
# 204795            8.0      720000.0
# 204796            8.0      728000.0
# 204797           11.0      575000.0
# 204798            5.0      535000.0
#
# [204799 rows x 6 columns]

# %%
scope_df = scope_df.drop_duplicates()
scope_df
# Out:
#             cbd_dist  min_dist_mrt  floor_area_sqm  lease_remain_years  \
# 0       10296.855747   1098.721074            60.0                  62
# 1       10296.855747   1098.721074            60.0                  62
# 2       10296.855747   1098.721074            69.0                  62
# 3       10296.855747   1098.721074            45.0                  62
# 4       10296.855747   1098.721074            61.0                  62
# ...              ...           ...             ...                 ...
# 204793  15294.493180   1199.607851           112.0                  94
# 204795  15294.493180   1199.607851           112.0                  94
# 204796  15294.493180   1199.607851           112.0                  94
# 204797  16037.700681   1782.270700            93.0                  95
# 204798  15737.566112   1928.447262            93.0                  95
#
#         storey_median  resale_price
# 0                 8.0      255000.0
# 1                11.0      275000.0
# 2                 5.0      310000.0
# 3                 8.0      253000.0
# 4                 5.0      290000.0
# ...               ...           ...
# 204793            5.0      665000.0
# 204795            8.0      720000.0
# 204796            8.0      728000.0
# 204797           11.0      575000.0
# 204798            5.0      535000.0
#
# [198472 rows x 6 columns]

# %%
#Checking and Handling for Skewness in the Data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# List of columns(continuous variables) for finding skewness
col = ['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median','resale_price']

for i in col:
    plt.figure(figsize=(8, 6))  
    sns.boxplot(data=df, x=i)
    plt.title(f'Boxplot of {i}')
    plt.xlabel(i)
    plt.show()

# %%
df1 = scope_df

# %%
# Apply a logarithmic transformation to the required columns only.
# One need to apply it and check, in some cases it will handle the skewness, and in other cases it might not have a great 
                                                                # effect on the data, so no need to apply for that columns
    
df1['floor_area_sqm'] = np.log(df1['floor_area_sqm'])
sns.boxplot(x='floor_area_sqm', data=df1)
plt.show()

df1['storey_median'] = np.log(df1['storey_median'])
sns.boxplot(x='storey_median', data=df1)
plt.show()

df1['resale_price'] = np.log(df1['resale_price'])
sns.boxplot(x='resale_price', data=df1)
plt.show()

# %%
df1.dtypes
# Out:
# cbd_dist              float64
# min_dist_mrt          float64
# floor_area_sqm        float64
# lease_remain_years      int64
# storey_median         float64
# resale_price          float64
# dtype: object

# %%
import seaborn as sns

corrMatrix = df1.corr()
plt.figure(figsize=(15, 10))
plt.title("Correlation Heatmap")
sns.heatmap(
    corrMatrix, 
    xticklabels=corrMatrix.columns,
    yticklabels=corrMatrix.columns,
    cmap='RdBu', 
    annot=True
)
# Out:
# <Axes: title={'center': 'Correlation Heatmap'}>

# %%
#Encoding Data

# %%
from sklearn.preprocessing import StandardScaler

X=df1[['cbd_dist','min_dist_mrt','floor_area_sqm','lease_remain_years','storey_median']]
y=df1['resale_price']

# Normalizing the encoded data
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
test_dataframe = pd.DataFrame(X)
test_dataframe
# Out:
#                0         1         2         3         4
# 0      -0.487490  0.585951 -1.775098 -0.666351  0.212497
# 1      -0.487490  0.585951 -1.775098 -0.666351  0.655707
# 2      -0.487490  0.585951 -1.229263 -0.666351 -0.441633
# 3      -0.487490  0.585951 -2.898629 -0.666351  0.212497
# 4      -0.487490  0.585951 -1.710544 -0.666351 -0.441633
# ...          ...       ...       ...       ...       ...
# 198467  0.648875  0.804168  0.662513  1.705411 -0.441633
# 198468  0.648875  0.804168  0.662513  1.705411  0.212497
# 198469  0.648875  0.804168  0.662513  1.705411  0.212497
# 198470  0.817866  2.064465 -0.063510  1.779529  0.655707
# 198471  0.749621  2.380644 -0.063510  1.779529 -0.441633
#
# [198472 rows x 5 columns]

# %%
#Splitting the Data for Training and Testing Purposes

# %%
from sklearn.model_selection import train_test_split

# test and train split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
#Decision Tree Regressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# Decision Tree Regressor
dtr = DecisionTreeRegressor()

# hyperparameters
param_grid = {
    'max_depth': [2, 5, 10, 15, 20, 22],
    'min_samples_split': [2, 3, 4, 5],
    'min_samples_leaf': [2, 3, 4, 5, 6, 7, 8, 9, 10, 15, 20],
    'max_features': ['auto', 'sqrt', 'log2']
}

# gridsearchcv
grid_search = GridSearchCV(estimator=dtr, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)
print("Best hyperparameters:", grid_search.best_params_)
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

# evalution metrics
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(" ")
print('Mean squared error:', mse)
print('Mean Absolute Error', mae)
print('Root Mean squared error:', rmse)
print(" ")
print('R-squared:', r2)
# Out:
# Best hyperparameters: {'max_depth': 22, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 3}
#
# Mean squared error: 0.015050424950732983
# Mean Absolute Error 0.09699172612031483
# Root Mean squared error: 0.12268017342151495
#
# R-squared: 0.8604255450984916

# %%
new_sample = np.array([[8740, 999, np.log(44), 55, np.log(11)]])
new_sample = scaler.transform(new_sample[:, :5])
new_pred = best_model.predict(new_sample)[0]
np.exp(new_pred)
# Out:
# 239365.37098609685

# %%
# Saving the model
import pickle
with open('modell.pkl', 'wb') as file:
    pickle.dump(best_model, file)
with open('scalerl.pkl', 'wb') as f:
    pickle.dump(scaler, f)
